# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

# %%
df=pd.read_csv("./data/SPEparam/alumBox.dat", header=None, sep=" ", usecols=[0,1])

dist=[10,20,30,40,50]
df.insert(loc=0, column="Distance",value=dist)
df=df.set_index("Distance")


df
# Out:
#                                     0         1
# Distance
# 10             coilsOn_Albox_X0_Y0_Z2  0.004337
# 20             coilsOn_Albox_X0_Y0_Z4  0.004327
# 30             coilsOn_Albox_X0_Y0_Z6  0.004301
# 40             coilsOn_Albox_X0_Y0_Z8  0.004294
# 50        coilsOn_Albox_X0_Y0_Zbottom  0.004235

# %%
df2=pd.read_csv("./data/SPEparam/shielding.dat", header=None, sep=" ", usecols=[0,1])
df2.insert(loc=0, column="Distance",value=dist)
df=df.set_index("Distance")

df2
# Out:
#    Distance                         0         1
# 0        10       coilsOn_sh_X0_Y0_Z2  0.004292
# 1        20       coilsOn_sh_X0_Y0_Z4  0.004303
# 2        30       coilsOn_sh_X0_Y0_Z6  0.004250
# 3        40       coilsOn_sh_X0_Y0_Z8  0.004238
# 4        50  coilsOn_sh_X0_Y0_Zbottom  0.004222

# %%
ax=df["Distance"].plot(marker='o')
# df2.transpose().plot(marker='o',ax=ax)
# fonttam=17
# plt.ylabel(ylabel='Vrms',fontsize=fonttam)
# plt.xticks(fontsize=fonttam)
# plt.yticks(fontsize=fonttam)
# plt.xticks(rotation=75)
