# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("./data/SPEparam/SPEparamsNoAmp.dat", header=None, sep=" ", index_col=0)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower

# %%
df=df.transpose()
df=df.iloc[0:2,:]
newCol= ["Peak/Valley", "PedestalSigma"]
df.insert(loc=0, column="Params",value=newCol)

# %%
df
# Out:
# 0         Params  coils_X0_Y0_Z0  coils_X0_Y0_Z15    noCoil
# 1    Peak/Valley        1.454450         1.716580  3.130520
# 2  PedestalSigma        0.039081         0.036201  0.034072

# %%
df=df.set_index("Params")

# %%
df.loc['Peak/Valley'].plot(kind='bar')
fonttam=17
plt.ylabel(ylabel='Peak/Valley ratio',fontsize=fonttam)
plt.xticks(fontsize=fonttam)
plt.yticks(fontsize=fonttam)
# Out:
# (array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df.loc['PedestalSigma'].plot(kind='bar')
fonttam=17
plt.ylabel(ylabel='Pedestal Sigma fit',fontsize=fonttam)
plt.xticks(fontsize=fonttam)
plt.yticks(fontsize=fonttam)
# Out:
# (array([0.   , 0.005, 0.01 , 0.015, 0.02 , 0.025, 0.03 , 0.035, 0.04 ,
#         0.045]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
