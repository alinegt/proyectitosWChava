# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("./data/SPEparam/SPEparams.dat", header=None, sep=" ", index_col=0)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
df=df.transpose()
df=df.iloc[0:1,:]
newCol= ["RMS_noise"]
# df.insert(loc=0, column="Params",value=newCol)
#newCol= ["Peak/Valley", "PedestalSigma"]
#newCol= ["RMS_noise"]
#df.insert(loc=0, column="Params",value=newCol)

df
# Out:
# 0  coilsOn_sh_X0_Y0_Z2  coilsOn_sh_X0_Y0_Z4  coilsOn_sh_X0_Y0_Z6  \
# 1             0.021656             0.021581             0.021296
#
# 0  coilsOn_sh_X0_Y0_Z8  coilsOn_sh_X0_Y0_Zbottom
# 1             0.021232                  0.021184

# %%
df.transpose().plot(marker='o')
fonttam=17
plt.ylabel(ylabel='Vrms',fontsize=fonttam)
plt.xticks(fontsize=fonttam)
plt.yticks(fontsize=fonttam)
plt.xticks(rotation=75)
# Out:
# (array([-0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5]),
#  [Text(-0.5, 0, ''),
#   Text(0.0, 0, 'coilsOn_sh_X0_Y0_Z2'),
#   Text(0.5, 0, ''),
#   Text(1.0, 0, 'coilsOn_sh_X0_Y0_Z4'),
#   Text(1.5, 0, ''),
#   Text(2.0, 0, 'coilsOn_sh_X0_Y0_Z6'),
#   Text(2.5, 0, ''),
#   Text(3.0, 0, 'coilsOn_sh_X0_Y0_Z8'),
#   Text(3.5, 0, ''),
#   Text(4.0, 0, 'coilsOn_sh_X0_Y0_Zbottom'),
#   Text(4.5, 0, '')])
