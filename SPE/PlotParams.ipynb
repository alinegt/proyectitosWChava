# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("./data/SPEparam/SPEparamsSh.dat", header=None, sep=" ", index_col=0)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
df=df.transpose()
df=df.iloc[0:1,:]
newCol= ["RMS_noise"]
# df.insert(loc=0, column="Params",value=newCol)
#newCol= ["Peak/Valley", "PedestalSigma"]
#newCol= ["RMS_noise"]
#df.insert(loc=0, column="Params",value=newCol)

df
# Out:
# 0  coilsOn_sh_X0_Y0_Z2  coilsOn_sh_X0_Y0_Z4  coilsOn_sh_X0_Y0_Z6  \
# 1             0.021656             0.021581             0.021296
#
# 0  coilsOn_sh_X0_Y0_Z8  coilsOn_sh_X0_Y0_Zbottom
# 1             0.021232                  0.021184

# %%
df2=pd.read_csv("./data/SPEparam/SPEparams.dat", header=None, sep=" ", index_col=0)
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100 # 200 e.g. is really fine, but slower
df2=df2.transpose()
df2=df2.iloc[0:1,:]
newCol= ["RMS_noise"]

#newCol= ["Peak/Valley", "PedestalSigma"]
newCol= ["NoShielding"]
df.insert(loc=0, column="NoShielding",value=newCol)
df.set_index("NoShielding")

df2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-ae97c31061ab> in <module>
#       9 newCol= ["NoShielding"]
#      10 df.insert(loc=0, column="Params",value=newCol)
# ---> 11 df.set_index("NoShielding")
#      12
#      13 df2
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4548
#    4549         if missing:
# -> 4550             raise KeyError(f"None of {missing} are in the columns")
#    4551
#    4552         if inplace:
#
# KeyError: "None of ['NoShielding'] are in the columns"

# %%
ax=df.transpose().plot(marker='o')
df2.transpose().plot(marker='o',ax=ax)
fonttam=17
plt.ylabel(ylabel='Vrms',fontsize=fonttam)
plt.xticks(fontsize=fonttam)
plt.yticks(fontsize=fonttam)
plt.xticks(rotation=75)
# Out:
# (array([-0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5]),
#  [Text(-0.5, 0, ''),
#   Text(0.0, 0, 'coilsOn_Albox_X0_Y0_Z2'),
#   Text(0.5, 0, ''),
#   Text(1.0, 0, 'coilsOn_Albox_X0_Y0_Z4'),
#   Text(1.5, 0, ''),
#   Text(2.0, 0, 'coilsOn_Albox_X0_Y0_Z6'),
#   Text(2.5, 0, ''),
#   Text(3.0, 0, 'coilsOn_Albox_X0_Y0_Z8'),
#   Text(3.5, 0, ''),
#   Text(4.0, 0, 'coilsOn_Albox_X0_Y0_Zbottom'),
#   Text(4.5, 0, '')])
